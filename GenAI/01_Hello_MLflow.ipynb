# %% [markdown]
# # Preliminares
#
# - pip install --upgrade mlflow
# - mlflow server
# - Navigate to the MLflow UI in your browser at http://127.0.0.1:5000.

# %%
import mlflow, os
import langchain
from langchain_community.llms import Ollama
from langchain_openai import ChatOpenAI # Usaremos esto para conectar con Ollama vía API compatible
from langchain_community.chat_models import ChatOllama
from langchain_core.messages import HumanMessage, SystemMessage

# %%
mlflow.set_tracking_uri("sqlite:///../mlflow.db")
mlflow.set_experiment("My Application")
# Out:
# 2025/12/31 09:55:29 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2025/12/31 09:55:29 INFO mlflow.store.db.utils: Updating database tables
# 2025/12/31 09:55:29 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2025/12/31 09:55:29 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# 2025/12/31 09:55:29 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2025/12/31 09:55:29 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# <Experiment: artifact_location='mlflow-artifacts:/1', creation_time=1767192444565, experiment_id='1', last_update_time=1767192444565, lifecycle_stage='active', name='My Application', tags={'mlflow.experimentKind': 'genai_development'}>

# %%
mlflow.langchain.autolog()

llm = ChatOllama(model="llama3.2:1b")

messages = [
    SystemMessage(content="You are a helpful weather assistant."),
    HumanMessage(content="What's the weather like in Seattle?")
]

response = llm.invoke(messages)

# %%
print(response.content)
# Out:
# Seattle, Washington is known for its mild and wet climate. The city experiences a marine west coast climate, with frequent overcast skies and cool temperatures.
#
# Typically, Seattle's temperature ranges from around 35°F (2°C) in January, which is one of the coldest months, to 63°F (17°C) in July, which is one of the warmest months. The average annual temperature is around 48°F (9°C).
#
# The weather in Seattle can be quite rainy, with an average of over 136 days per year with precipitation. However, the rain is usually light to moderate, and the city's proximity to the ocean helps regulate its climate.
#
# Here's a breakdown of Seattle's typical weather patterns:
#
# * Winter (December to February): Cool and wet, with average highs around 45°F (7°C) and lows around 35°F (2°C).
# * Spring (March to May): Mild and rainy, with average highs around 55°F (13°C) and lows around 45°F (7°C).
# ...
