# %%
# Basic Libraries
import mlflow, warnings

# Machine Learning
import optuna, sklearn
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_breast_cancer
from sklearn.metrics import accuracy_score, f1_score, log_loss

warnings.filterwarnings("ignore")

# %%
# The set_experiment API creates a new experiment if it doesn't exist.
mlflow.set_experiment("Hyperparameter Tuning Experiment")
# Out:
# <Experiment: artifact_location='file:///Users/guane/Documentos/GitHub/MLOPS/Notebooks/mlruns/395073105550929572', creation_time=1767105597527, experiment_id='395073105550929572', last_update_time=1767105597527, lifecycle_stage='active', name='Hyperparameter Tuning Experiment', tags={}>

# %%
X, y = load_breast_cancer(return_X_y=True, as_frame=True)
X_train, X_val, y_train, y_val = train_test_split(X, y, random_state=0)

X_train.shape, X_val.shape, y_train.shape, y_val.shape
# Out:
# ((426, 30), (143, 30), (426,), (143,))

# %%
def objective(trial):
    """
    Optuna objective function for Random Forest Classifier hyperparameter tuning.
    
    Args:
        trial: Optuna trial object
        
    Returns:
        float: Negative accuracy (to minimize) or log_loss (to minimize)
    """
    # Setting nested=True will create a child run under the parent run.
    with mlflow.start_run(nested=True, run_name=f"trial_{trial.number}") as child_run:
        # Hyperparameter suggestions
        rf_max_depth = trial.suggest_int("rf_max_depth", 2, 32)
        rf_n_estimators = trial.suggest_int("rf_n_estimators", 50, 300, step=10)
        rf_max_features = trial.suggest_float("rf_max_features", 0.2, 1.0)
        rf_min_samples_split = trial.suggest_int("rf_min_samples_split", 2, 10)
        
        params = {
            "max_depth": rf_max_depth,
            "n_estimators": rf_n_estimators,
            "max_features": rf_max_features,
            "min_samples_split": rf_min_samples_split,
            "random_state": 42,
        }
        
        # Log current trial's parameters
        mlflow.log_params(params)

        # Train classifier
        classifier_obj = sklearn.ensemble.RandomForestClassifier(**params)
        classifier_obj.fit(X_train, y_train)

        # Predictions
        y_pred = classifier_obj.predict(X_val)
        y_pred_proba = classifier_obj.predict_proba(X_val)
        
        # Calculate metrics
        accuracy = accuracy_score(y_val, y_pred)
        f1 = f1_score(y_val, y_pred, average='binary')  # Use 'macro' for multiclass
        logloss = log_loss(y_val, y_pred_proba)
        
        # Log metrics
        mlflow.log_metrics({
            "accuracy": accuracy,
            "f1_score": f1,
            "log_loss": logloss
        })

        # Log the model with signature
        signature = mlflow.models.infer_signature(X_train, classifier_obj.predict(X_train))
        mlflow.sklearn.log_model(
            classifier_obj, 
            artifact_path="model",
            signature=signature,
            input_example=X_train.iloc[:5]
        )
        
        # Make it easy to retrieve the best-performing child run later
        trial.set_user_attr("run_id", child_run.info.run_id)
        
        # Return negative accuracy to minimize (Optuna minimizes by default)
        # Or return log_loss directly (lower is better)
        return -accuracy  # Or: return logloss

# %%
with mlflow.start_run(run_name="classification_study") as run:
    # Log the experiment settings
    n_trials = 30
    mlflow.log_param("n_trials", n_trials)
    mlflow.log_param("task_type", "classification")

    # Create study - direction depends on what objective returns
    # If returning -accuracy: use "minimize"
    # If returning log_loss: use "minimize"
    # If returning accuracy: use "maximize"
    study = optuna.create_study(direction="minimize")  # Because we return -accuracy
    study.optimize(objective, n_trials=n_trials)

    # Log the best trial and its run ID
    mlflow.log_params(study.best_trial.params)
    
    # Log best metrics (convert back to positive accuracy if needed)
    best_accuracy = -study.best_value  # Convert back from negative
    mlflow.log_metrics({
        "best_accuracy": best_accuracy,
        "best_negative_accuracy": study.best_value
    })
    
    if best_run_id := study.best_trial.user_attrs.get("run_id"):
        mlflow.log_param("best_child_run_id", best_run_id)
        
    print(f"Best accuracy: {best_accuracy:.4f}")
    print(f"Best parameters: {study.best_trial.params}")
# Out:
# [I 2025-12-30 09:59:28,168] A new study created in memory with name: no-name-8d612e0b-698a-4d94-94d5-c544ffcb7e93
# 2025/12/30 09:59:30 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# [I 2025-12-30 09:59:35,272] Trial 0 finished with value: -0.965034965034965 and parameters: {'rf_max_depth': 30, 'rf_n_estimators': 270, 'rf_max_features': 0.8250166096343861, 'rf_min_samples_split': 10}. Best is trial 0 with value: -0.965034965034965.
# 2025/12/30 09:59:36 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# [I 2025-12-30 09:59:43,231] Trial 1 finished with value: -0.972027972027972 and parameters: {'rf_max_depth': 16, 'rf_n_estimators': 220, 'rf_max_features': 0.2322013447948213, 'rf_min_samples_split': 4}. Best is trial 1 with value: -0.972027972027972.
# 2025/12/30 09:59:44 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# [I 2025-12-30 09:59:49,482] Trial 2 finished with value: -0.972027972027972 and parameters: {'rf_max_depth': 25, 'rf_n_estimators': 250, 'rf_max_features': 0.4261283756782451, 'rf_min_samples_split': 3}. Best is trial 1 with value: -0.972027972027972.
# 2025/12/30 09:59:49 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# [I 2025-12-30 09:59:54,143] Trial 3 finished with value: -0.9790209790209791 and parameters: {'rf_max_depth': 4, 'rf_n_estimators': 60, 'rf_max_features': 0.36116117487694643, 'rf_min_samples_split': 5}. Best is trial 3 with value: -0.9790209790209791.
# 2025/12/30 09:59:55 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# [I 2025-12-30 09:59:59,229] Trial 4 finished with value: -0.972027972027972 and parameters: {'rf_max_depth': 30, 'rf_n_estimators': 150, 'rf_max_features': 0.6930987689619693, 'rf_min_samples_split': 2}. Best is trial 3 with value: -0.9790209790209791.
# 2025/12/30 09:59:59 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# [I 2025-12-30 10:00:04,140] Trial 5 finished with value: -0.972027972027972 and parameters: {'rf_max_depth': 16, 'rf_n_estimators': 140, 'rf_max_features': 0.252072244764423, 'rf_min_samples_split': 6}. Best is trial 3 with value: -0.9790209790209791.
# 2025/12/30 10:00:06 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# [I 2025-12-30 10:00:10,484] Trial 6 finished with value: -0.972027972027972 and parameters: {'rf_max_depth': 12, 'rf_n_estimators': 300, 'rf_max_features': 0.8286985593000986, 'rf_min_samples_split': 6}. Best is trial 3 with value: -0.9790209790209791.
# 2025/12/30 10:00:12 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# [I 2025-12-30 10:00:16,828] Trial 7 finished with value: -0.9790209790209791 and parameters: {'rf_max_depth': 20, 'rf_n_estimators': 260, 'rf_max_features': 0.5199098033383867, 'rf_min_samples_split': 3}. Best is trial 3 with value: -0.9790209790209791.
# 2025/12/30 10:00:18 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# [I 2025-12-30 10:00:22,350] Trial 8 finished with value: -0.972027972027972 and parameters: {'rf_max_depth': 6, 'rf_n_estimators': 260, 'rf_max_features': 0.2410463338819322, 'rf_min_samples_split': 9}. Best is trial 3 with value: -0.9790209790209791.
# 2025/12/30 10:00:23 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# [I 2025-12-30 10:00:27,791] Trial 9 finished with value: -0.9790209790209791 and parameters: {'rf_max_depth': 5, 'rf_n_estimators': 300, 'rf_max_features': 0.5432678825380589, 'rf_min_samples_split': 8}. Best is trial 3 with value: -0.9790209790209791.
# 2025/12/30 10:00:28 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# [I 2025-12-30 10:00:32,201] Trial 10 finished with value: -0.972027972027972 and parameters: {'rf_max_depth': 10, 'rf_n_estimators': 60, 'rf_max_features': 0.39471216578533364, 'rf_min_samples_split': 5}. Best is trial 3 with value: -0.9790209790209791.
# 2025/12/30 10:00:32 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# [I 2025-12-30 10:00:37,848] Trial 11 finished with value: -0.9790209790209791 and parameters: {'rf_max_depth': 22, 'rf_n_estimators': 50, 'rf_max_features': 0.5536469027078701, 'rf_min_samples_split': 4}. Best is trial 3 with value: -0.9790209790209791.
# 2025/12/30 10:00:38 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# [I 2025-12-30 10:00:42,988] Trial 12 finished with value: -0.972027972027972 and parameters: {'rf_max_depth': 21, 'rf_n_estimators': 110, 'rf_max_features': 0.39797678241055845, 'rf_min_samples_split': 2}. Best is trial 3 with value: -0.9790209790209791.
# 2025/12/30 10:00:43 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# [I 2025-12-30 10:00:48,603] Trial 13 finished with value: -0.9790209790209791 and parameters: {'rf_max_depth': 3, 'rf_n_estimators': 180, 'rf_max_features': 0.9831407572425975, 'rf_min_samples_split': 7}. Best is trial 3 with value: -0.9790209790209791.
# 2025/12/30 10:00:49 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# [I 2025-12-30 10:00:53,526] Trial 14 finished with value: -0.972027972027972 and parameters: {'rf_max_depth': 10, 'rf_n_estimators': 200, 'rf_max_features': 0.4779021029439119, 'rf_min_samples_split': 4}. Best is trial 3 with value: -0.9790209790209791.
# 2025/12/30 10:00:54 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# [I 2025-12-30 10:00:59,475] Trial 15 finished with value: -0.9790209790209791 and parameters: {'rf_max_depth': 20, 'rf_n_estimators': 90, 'rf_max_features': 0.6526178576549482, 'rf_min_samples_split': 5}. Best is trial 3 with value: -0.9790209790209791.
# 2025/12/30 10:01:00 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# [I 2025-12-30 10:01:04,877] Trial 16 finished with value: -0.972027972027972 and parameters: {'rf_max_depth': 25, 'rf_n_estimators': 220, 'rf_max_features': 0.3339566139725315, 'rf_min_samples_split': 3}. Best is trial 3 with value: -0.9790209790209791.
# 2025/12/30 10:01:05 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# [I 2025-12-30 10:01:09,841] Trial 17 finished with value: -0.965034965034965 and parameters: {'rf_max_depth': 13, 'rf_n_estimators': 120, 'rf_max_features': 0.49959247265138707, 'rf_min_samples_split': 6}. Best is trial 3 with value: -0.9790209790209791.
# 2025/12/30 10:01:10 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# [I 2025-12-30 10:01:14,567] Trial 18 finished with value: -0.972027972027972 and parameters: {'rf_max_depth': 2, 'rf_n_estimators': 170, 'rf_max_features': 0.3291909128223726, 'rf_min_samples_split': 3}. Best is trial 3 with value: -0.9790209790209791.
# 2025/12/30 10:01:15 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# [I 2025-12-30 10:01:19,128] Trial 19 finished with value: -0.972027972027972 and parameters: {'rf_max_depth': 18, 'rf_n_estimators': 80, 'rf_max_features': 0.6500783019872516, 'rf_min_samples_split': 5}. Best is trial 3 with value: -0.9790209790209791.
# 2025/12/30 10:01:20 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# [I 2025-12-30 10:01:24,463] Trial 20 finished with value: -0.972027972027972 and parameters: {'rf_max_depth': 25, 'rf_n_estimators': 230, 'rf_max_features': 0.7480175631523414, 'rf_min_samples_split': 7}. Best is trial 3 with value: -0.9790209790209791.
# 2025/12/30 10:01:25 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# [I 2025-12-30 10:01:29,899] Trial 21 finished with value: -0.972027972027972 and parameters: {'rf_max_depth': 7, 'rf_n_estimators': 300, 'rf_max_features': 0.5487679305097305, 'rf_min_samples_split': 8}. Best is trial 3 with value: -0.9790209790209791.
# 2025/12/30 10:01:31 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# [I 2025-12-30 10:01:35,166] Trial 22 finished with value: -0.9790209790209791 and parameters: {'rf_max_depth': 6, 'rf_n_estimators': 280, 'rf_max_features': 0.5581582900739938, 'rf_min_samples_split': 8}. Best is trial 3 with value: -0.9790209790209791.
# 2025/12/30 10:01:36 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# [I 2025-12-30 10:01:40,466] Trial 23 finished with value: -0.972027972027972 and parameters: {'rf_max_depth': 4, 'rf_n_estimators': 290, 'rf_max_features': 0.4723890766393164, 'rf_min_samples_split': 7}. Best is trial 3 with value: -0.9790209790209791.
# 2025/12/30 10:01:41 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# [I 2025-12-30 10:01:45,495] Trial 24 finished with value: -0.965034965034965 and parameters: {'rf_max_depth': 8, 'rf_n_estimators': 240, 'rf_max_features': 0.317218298803072, 'rf_min_samples_split': 9}. Best is trial 3 with value: -0.9790209790209791.
# 2025/12/30 10:01:46 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# [I 2025-12-30 10:01:50,674] Trial 25 finished with value: -0.972027972027972 and parameters: {'rf_max_depth': 14, 'rf_n_estimators': 200, 'rf_max_features': 0.5996633581033172, 'rf_min_samples_split': 8}. Best is trial 3 with value: -0.9790209790209791.
# 2025/12/30 10:01:51 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# [I 2025-12-30 10:01:55,926] Trial 26 finished with value: -0.972027972027972 and parameters: {'rf_max_depth': 10, 'rf_n_estimators': 270, 'rf_max_features': 0.4401405275979492, 'rf_min_samples_split': 10}. Best is trial 3 with value: -0.9790209790209791.
# 2025/12/30 10:01:56 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# [I 2025-12-30 10:02:00,882] Trial 27 finished with value: -0.9790209790209791 and parameters: {'rf_max_depth': 4, 'rf_n_estimators': 200, 'rf_max_features': 0.5139096371103042, 'rf_min_samples_split': 5}. Best is trial 3 with value: -0.9790209790209791.
# 2025/12/30 10:02:01 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# [I 2025-12-30 10:02:05,897] Trial 28 finished with value: -0.972027972027972 and parameters: {'rf_max_depth': 19, 'rf_n_estimators': 250, 'rf_max_features': 0.3686743921074559, 'rf_min_samples_split': 2}. Best is trial 3 with value: -0.9790209790209791.
# 2025/12/30 10:02:07 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# [I 2025-12-30 10:02:11,388] Trial 29 finished with value: -0.972027972027972 and parameters: {'rf_max_depth': 27, 'rf_n_estimators': 280, 'rf_max_features': 0.7527978107450046, 'rf_min_samples_split': 4}. Best is trial 3 with value: -0.9790209790209791.
# Best accuracy: 0.9790
# Best parameters: {'rf_max_depth': 4, 'rf_n_estimators': 60, 'rf_max_features': 0.36116117487694643, 'rf_min_samples_split': 5}
